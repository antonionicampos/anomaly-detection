# %%
import pandas as pd
import plotly.graph_objects as go
import pyreadr

# %%
normal = pyreadr.read_r('.\\data\\TEP_FaultFree_Training.RData')['fault_free_training']
faulty = pyreadr.read_r('.\\data\\TEP_Faulty_Training.RData')['faulty_training']

print(f'Normal data: {normal.shape}')
print(f'Faulty data: {faulty.shape}')

normal.head(5)
# Out:
# Normal data: (250000, 55)
# Faulty data: (5000000, 55)
#    faultNumber  simulationRun  sample  xmeas_1  xmeas_2  xmeas_3  xmeas_4  \
# 0          0.0            1.0       1  0.25038   3674.0   4529.0   9.2320
# 1          0.0            1.0       2  0.25109   3659.4   4556.6   9.4264
# 2          0.0            1.0       3  0.25038   3660.3   4477.8   9.4426
# 3          0.0            1.0       4  0.24977   3661.3   4512.1   9.4776
# 4          0.0            1.0       5  0.29405   3679.0   4497.0   9.3381
#
#    xmeas_5  xmeas_6  xmeas_7  ...   xmv_2   xmv_3   xmv_4   xmv_5   xmv_6  \
# 0   26.889   42.402   2704.3  ...  53.744  24.657  62.544  22.137  39.935
# 1   26.721   42.576   2705.0  ...  53.414  24.588  59.259  22.084  40.176
# 2   26.875   42.070   2706.2  ...  54.357  24.666  61.275  22.380  40.244
# 3   26.758   42.063   2707.2  ...  53.946  24.725  59.856  22.277  40.257
# 4   26.889   42.650   2705.1  ...  53.658  28.797  60.717  21.947  39.144
#
# ...

# %%
simulation = 20.0
normal_sim = normal[normal['simulationRun'] == simulation].iloc[:, 3:]
normal_sim.index = pd.timedelta_range(start="0 minutes", periods=500, freq='3T', name='timestamp')

normal_sim.head()
# Out:
#                  xmeas_1  xmeas_2  xmeas_3  xmeas_4  xmeas_5  xmeas_6  \
# timestamp
# 0 days 00:00:00  0.25086   3635.8   4517.5   9.3854   26.498   42.566
# 0 days 00:03:00  0.25286   3699.3   4499.0   9.3105   26.846   42.494
# 0 days 00:06:00  0.24954   3672.9   4538.4   9.4023   27.058   42.329
# 0 days 00:09:00  0.24747   3671.4   4491.5   9.2545   26.840   42.348
# 0 days 00:12:00  0.21042   3635.6   4510.0   9.3230   26.556   42.227
#
#                  xmeas_7  xmeas_8  xmeas_9  xmeas_10  ...   xmv_2   xmv_3  \
# timestamp                                             ...
# 0 days 00:00:00   2707.0   74.034   120.40   0.33607  ...  53.882  24.611
# 0 days 00:03:00   2707.9   74.511   120.41   0.33730  ...  54.104  24.414
# 0 days 00:06:00   2704.2   75.499   120.40   0.33821  ...  53.631  24.748
# 0 days 00:09:00   2705.2   74.795   120.40   0.34186  ...  54.192  24.952
# 0 days 00:12:00   2704.0   75.545   120.39   0.34838  ...  54.190  20.442
#
# ...

# %%
fig = go.Figure([
    go.Scatter(x=normal_sim.index, y=normal_sim[col], name=col) for col in normal_sim.columns
])
fig.show()
# Out:
# <div>                            <div id="65109c78-9878-4da7-9e02-c326b9320c30" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65109c78-9878-4da7-9e02-c326b9320c30")) {                    Plotly.newPlot(                        "65109c78-9878-4da7-9e02-c326b9320c30",                        [{"name": "xmeas_1", "type": "scatter", "x": [0, 180000000000, 360000000000, 540000000000, 720000000000, 900000000000, 1080000000000, 1260000000000, 1440000000000, 1620000000000, 1800000000000, 1980000000000, 2160000000000, 2340000000000, 2520000000000, 2700000000000, 2880000000000, 3060000000000, 3240000000000, 3420000000000, 3600000000000, 3780000000000, 3960000000000, 4140000000000, 4320000000000, 4500000000000, 4680000000000, 4860000000000, 5040000000000, 5220
# ...

# %%
normal_sim.index.dtype
# Out:
# dtype('<m8[ns]')
